# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Zip_MedianValuePerSqft_AllHomes.csv",encoding='latin-1')
#df=pd.read_csv("Zip_MedianRentalPrice_1Bedroom.csv",encoding='latin-1')
#df=df.drop(columns=["RegionID"])
#df=df.dropna()
df.head()
# Out:
#    RegionID  RegionName      City State                             Metro  \
# 0     61639       10025  New York    NY       New York-Newark-Jersey City
# 1     84654       60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637       10023  New York    NY       New York-Newark-Jersey City
# 3     91982       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616       60614   Chicago    IL          Chicago-Naperville-Elgin
#
#         CountyName  SizeRank  1996-04  1996-05  1996-06  ...  2018-10  \
# 0  New York County         1    200.0    200.0    201.0  ...     1323
# 1      Cook County         2    156.0    157.0    157.0  ...      477
# 2  New York County         3    359.0    359.0    359.0  ...     1591
# 3    Harris County         4     67.0     68.0     68.0  ...      113
# 4      Cook County         5    199.0    200.0    201.0  ...      523
#
#    2018-11  2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  \
# ...

# %%
#df_tx=df[(df.State=="TX")]
df_atx = df[((df.State=="TX") & ((df.CountyName == "Travis County") | (df.CountyName == "Williamson County")))]
df_atx.head()
# Out:
#      RegionID  RegionName          City State              Metro  \
# 14      92593       78660  Pflugerville    TX  Austin-Round Rock
# 32      92551       78613    Cedar Park    TX  Austin-Round Rock
# 66      92617       78704        Austin    TX  Austin-Round Rock
# 86      92654       78745        Austin    TX  Austin-Round Rock
# 165     92576       78641       Leander    TX  Austin-Round Rock
#
#             CountyName  SizeRank  1996-04  1996-05  1996-06  ...  2018-10  \
# 14       Travis County        15     69.0     69.0     69.0  ...      126
# 32   Williamson County        33     77.0     77.0     77.0  ...      137
# 66       Travis County        67    139.0    138.0    139.0  ...      366
# 86       Travis County        87    100.0    100.0     99.0  ...      223
# 165  Williamson County       166     75.0     75.0     75.0  ...      134
#
#      2018-11  2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  \
# ...

# %%
#df_atx_low=df_atx[df["2019-07"]<250]
#df_final.describe()

#df.dropna(subset=["2019-07"], inplace=True)

#df_atx.describe()
#help(df_atx.dropna)
df_atx_drop = df_atx.set_index("RegionName")
df_atx_drop = df_atx_drop.drop(columns=["RegionID","City","State","Metro","CountyName","SizeRank"])
#df_atx_drop.head()
df_atx_drop.sort_values(by=['2019-07'], ascending = False, inplace=True)

# %%
#df_atx_drop.sort_values(by=['2019-07'], ascending=False).head()
#df_atx_drop.head()

# %%
df_atx_t=df_atx_drop.transpose()

# %%
df_atx_t.head()
# Out:
# RegionName  78703  78701  78704  78702  78751  78722  78756  78705  78746  \
# 1996-04     155.0  121.0  139.0   64.0  103.0   52.0  132.0  126.0  162.0
# 1996-05     154.0  123.0  138.0   64.0  103.0   53.0  133.0  126.0  162.0
# 1996-06     152.0  125.0  139.0   65.0  104.0   55.0  133.0  127.0  162.0
# 1996-07     151.0  126.0  139.0   66.0  104.0   56.0  133.0  127.0  162.0
# 1996-08     150.0  128.0  140.0   67.0  105.0   58.0  134.0  128.0  162.0
#
# RegionName  78757  ...  78664  78641  78754  76530  78660  78653  78634  \
# 1996-04     105.0  ...   74.0   75.0   67.0    NaN   69.0   72.0   72.0
# 1996-05     106.0  ...   74.0   75.0   67.0    NaN   69.0   71.0   72.0
# 1996-06     106.0  ...   73.0   75.0   67.0    NaN   69.0   71.0   72.0
# 1996-07     107.0  ...   73.0   75.0   67.0    NaN   70.0   70.0   73.0
# 1996-08     108.0  ...   74.0   75.0   67.0    NaN   70.0   69.0   72.0
#
# RegionName  78617  78665  76511
# 1996-04      68.0   71.0    NaN
# ...

# %%
#df_atx_t.plot(y=[78735], figsize=(10,5), grid=True)
#df_atx_t.plot(y=[78702], figsize=(10,5), grid=True)
df_atx_t.plot(y=[78757], figsize=(15,10), grid=True)

# %%
cols=list(df_atx_t.columns)
df_atx_t.plot(y=cols, figsize=(15,10), grid=True)

# %%
df_atx_rolling=df_atx_t.rolling(6).mean()

# %%
df_atx_rolling.plot(y=cols, figsize=(15,15), grid=True)

# %%
#help(df_atx_rolling.plot.hist)
t=df_atx_rolling.transpose()
grph=t["2019-07"]
grph.plot.hist(bins=30)
#outl=t.plot.hist(by=["2019-07"])
#plt.hist(df.loc[df['Pos'] == "PG"].GMM_Class)

# %%
df_atx_delta1=df_atx_t.diff()
df_atx_delta2=df_atx_delta1.diff()

df_atx_delta1_rolling=df_atx_delta1.rolling(3).mean()
df_atx_delta2_rolling=df_atx_delta1.rolling(3).mean()

# %%
#df_atx_delta1.head()
#help(df_atx.sort_values)
df_atx_delta1_rolling.tail()
# Out:
# RegionName     78703     78731     78746     78756     78633     76578  \
# 2019-03     5.333333  2.666667  3.666667  2.666667  0.333333  0.333333
# 2019-04     5.666667  3.000000  5.000000  4.000000 -0.666667 -1.666667
# 2019-05     4.333333  2.333333  5.000000  4.333333 -1.333333 -2.666667
# 2019-06     0.000000 -0.333333  2.000000  1.666667 -1.666667 -2.666667
# 2019-07    -4.666667 -2.666667 -2.000000 -1.666667 -1.333333 -1.000000
#
# RegionName     78669     78736     78730     78733  ...     78741     78727  \
# 2019-03     1.666667  1.666667  2.000000  2.333333  ...  0.666667  1.333333
# 2019-04     1.000000  1.333333  3.000000  2.666667  ... -0.333333  1.000000
# 2019-05     0.666667  1.000000  2.666667  2.333333  ... -1.666667  0.666667
# 2019-06    -0.333333 -0.333333  1.333333  0.666667  ... -0.333333  0.666667
# 2019-07    -1.000000 -1.000000 -1.000000 -1.000000  ...  0.666667  0.666667
#
# RegionName     78626     78705     78752     78722     78729     78702  \
# ...

# %%
df_atx_delta1_rolling.sort_values(by = "2019-07", axis=1, inplace = True)

# %%
df_atx_delta1_rolling.plot(y=cols, figsize=(15,10), grid=True)

# %%
df_atx_delta1.plot(y=cols, figsize=(15,10), grid=True)
